# %% [markdown]
# <h4>Jupyter Note Book Options</h4 >

# %% [markdown]
# from IPython.display import display, HTML
#
# <div style="background-color: #cce5ff; color: #004085; padding: 20px; border-radius: 5px; margin-top: 20px; border: 1px solid #b8daff;">Matplotlib Methods.</div>

# %%
# Matplotlib methods

import matplotlib.pyplot as plt
import numpy as np

# Sample data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a plot
plt.plot(x, y)
plt.title('Sine Wave')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# from IPython.display import display, HTML
#
# <div style="background-color: #cce5ff; color: #004085; padding: 20px; border-radius: 5px; margin-top: 20px; border: 1px solid #b8daff;">Seaborn Methods</div>

# %%
# Seaborn Methods

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Create the DataFrame
df = pd.DataFrame()

df['x'] = np.linspace(0, 10, 100)
df['y'] = np.sin(df['x'])

# Sample data
sns.scatterplot(data=df, x='x', y='y')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# from IPython.display import display, HTML
#
# <div style="background-color: #cce5ff; color: #004085; padding: 20px; border-radius: 5px; margin-top: 20px; border: 1px solid #b8daff;">Plotly Methods - Bad Graph Using Discrete Value for Scatter Plot</div>

# %%
# Plotly Methods

# Install Plotly if it's not already installed
# %pip install plotly

# Import Plotly Express
import plotly.express as px

# Sample data
df = px.data.iris()

# Create a plot
fig = px.scatter(df, x='sepal_width', y='sepal_length', color='species', title='Iris Dataset')
fig.show()

# %%
### Let fix Iris Dataset
# %reset -f 

import plotly.express as px
import plotly.graph_objects as go
import pandas
import numpy as np

# Load the Iris dataset
Iris_Data = px.data.iris()

# Group by species and calculate the mean and standard error of sepal_width
Iris_group = Iris_Data.groupby('species').agg(
    mean_sepal_width=('sepal_width', 'mean'),
    se_sepal_width=('sepal_width', lambda x: np.std(x) / np.sqrt(len(x)))
).reset_index()

# Calculate the 95% confidence interval
Iris_group['ci_sepal_width'] = 1.96 * Iris_group['se_sepal_width']

Iris_group['mean_sepal_width'] = Iris_group['mean_sepal_width'].apply(lambda x: round(x, 2))

# Create a bar chart with error bars
fig = px.bar(
    Iris_group,
    x='species',
    y='mean_sepal_width',
    error_y='ci_sepal_width',
    title='Average Sepal Width by Species with 95% Confidence Interval',
    labels={'mean_sepal_width': 'Average Sepal Width'}
)

# Format the y-axis to have two decimal places
fig.update_layout(
    yaxis=dict(
        tickformat=".0f"
    )
)
fig.show()

# Group by species and calculate the mean and standard error of sepal_length
Iris_group = Iris_Data.groupby('species').agg(
    mean_sepal_length=('sepal_length', 'mean'),
    se_sepal_length=('sepal_length', lambda x: np.std(x) / np.sqrt(len(x)))
).reset_index()

# Calculate the 95% confidence interval
Iris_group['ci_sepal_length'] = 1.96 * Iris_group['se_sepal_length']

Iris_group['mean_sepal_length'] = Iris_group['mean_sepal_length'].apply(lambda x: round(x, 2))

# Create a bar chart with error bars
fig = px.bar(
    Iris_group,
    x='species',
    y='mean_sepal_length',
    error_y='ci_sepal_length',
    title='Average Sepal Length by Species with 95% Confidence Interval',
    labels={'mean_sepal_length': 'Average Sepal Length'}
)

# Format the y-axis to have two decimal places
fig.update_layout(
    yaxis=dict(
        tickformat=".0f"
    )
)

fig.show()

# %% [markdown]
# from IPython.display import display, HTML
#
# <div style="background-color: #cce5ff; color: #004085; padding: 20px; border-radius: 5px; margin-top: 20px; border: 1px solid #b8daff;">Altair Methods</div>

# %%
# Altair Methods

# %pip install altair
# %pip install vega_datasets
import altair as alt
from vega_datasets import data

# Sample data
cars = data.cars()

# Create a plot
chart = alt.Chart(cars).mark_point().encode(
    x='Horsepower',
    y='Miles_per_Gallon',
    color='Origin',
    tooltip=['Name', 'Origin', 'Horsepower', 'Miles_per_Gallon']
).interactive()

# Show the plot
chart
# Out:
# Requirement already satisfied: altair in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (5.3.0)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from altair) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from altair) (4.23.0)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from altair) (2.1.1)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from altair) (24.1)
# Requirement already satisfied: pandas>=0.25 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from altair) (2.2.2)
# Requirement already satisfied: toolz in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from altair) (0.12.1)
# Requirement already satisfied: attrs>=22.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonschema>=3.0->altair) (0.19.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=0.25->altair) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=0.25->altair) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=0.25->altair) (2024.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jinja2->altair) (2.1.5)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=0.25->altair) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: vega_datasets in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.9.0)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from vega_datasets) (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas->vega_datasets) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas->vega_datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas->vega_datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas->vega_datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->vega_datasets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# alt.Chart(...)

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h3>End of Notebook and Examples</h3>
# </div>
