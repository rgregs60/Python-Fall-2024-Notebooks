# %%
# !pip install boto3
import boto3
client = boto3.client('appstream')

resp = client.create_streaming_url(
    StackName='FleetCommonStack',
    FleetName='FleetCommon',
    UserId='student123',
    Validity=3600
)

print(resp['StreamingURL'])
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 3.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 34.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 13.9 MB/s eta 0:00:00
# ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 get_ipython().system('pip install boto3')
# ----> 2 import boto3
#       3 client = boto3.client('appstream')
#       5 resp = client.create_streaming_url(
#       6     StackName='FleetCommonStack',
#       7     FleetName='FleetCommon',
#       8     UserId='student123',
#       9     Validity=3600
#      10 )
#
# ModuleNotFoundError: No module named 'boto3'

# %%
import sys
# !{sys.executable} -m pip install boto3
# Out:
# ...
#   Using cached boto3-1.41.5-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached botocore-1.41.5-py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# ...
#   Using cached s3transfer-0.15.0-py3-none-any.whl.metadata (1.7 kB)
# ...
# Using cached boto3-1.41.5-py3-none-any.whl (139 kB)
# Using cached botocore-1.41.5-py3-none-any.whl (14.3 MB)
# Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Using cached s3transfer-0.15.0-py3-none-any.whl (85 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [boto3]32m1/4 [botocore]
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip

# %%
import sys
print(sys.executable)
print(sys.path)
# Out:
# /usr/local/bin/python3
# ['/Library/Frameworks/Python.framework/Versions/3.13/lib/python313.zip', '/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13', '/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/lib-dynload', '', '/Users/rudolphsurovcik/Library/Python/3.13/lib/python/site-packages', '/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages']

# %%
import sys
print(sys.executable)  # should show /usr/local/bin/python3
# !{sys.executable} -m pip install boto3
# Out:
# /usr/local/bin/python3
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip

# %%
import boto3

client = boto3.client('appstream')

resp = client.create_streaming_url(
    StackName='FleetCommonStack',
    FleetName='FleetCommon',
    UserId='student123',
    Validity=3600
)

print(resp['StreamingURL'])
# Out:
# ---------------------------------------------------------------------------
# NoRegionError                             Traceback (most recent call last)
# Cell In[7], line 3
#       1 import boto3
# ----> 3 client = boto3.client('appstream')
#       5 resp = client.create_streaming_url(
#       6     StackName='FleetCommonStack',
#       7     FleetName='FleetCommon',
#       8     UserId='student123',
#       9     Validity=3600
#      10 )
#      12 print(resp['StreamingURL'])
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/boto3/__init__.py:93, in client(*args, **kwargs)
#      87 def client(*args, **kwargs):
#      88     """
#      89     Create a low-level service client by name using the default session.
#      90
#      91     See :py:meth:`boto3.session.Session.client`.
#      92     """
# ---> 93     return _get_default_session().client(*args, **kwargs)
#
# ...

# %%
import boto3

client = boto3.client(
    'appstream',
    region_name='us-east-1'   # or your actual region
)

resp = client.create_streaming_url(
    StackName='FleetCommonStack',
    FleetName='FleetCommon',
    UserId='student123',
    Validity=3600
)

print(resp['StreamingURL'])
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# Cell In[8], line 8
#       1 import boto3
#       3 client = boto3.client(
#       4     'appstream',
#       5     region_name='us-east-1'   # or your actual region
#       6 )
# ----> 8 resp = client.create_streaming_url(
#       9     StackName='FleetCommonStack',
#      10     FleetName='FleetCommon',
#      11     UserId='student123',
#      12     Validity=3600
#      13 )
#      15 print(resp['StreamingURL'])
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/botocore/client.py:602, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     598     raise TypeError(
#     599         f"{py_operation_name}() only accepts keyword arguments."
#     600     )
#     601 # The "self" in this scope is referring to the BaseClient.
# ...
