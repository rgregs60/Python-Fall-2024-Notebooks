# %%
import textwrap

import matplotlib.pyplot as plt

# Data
years = [2020, 2025, 2028, 2030, 2035, 2040, 2050]
milestone_index = [0, 1, 2, 3, 4, 5, 6]
milestones = [
    "GPT-2 released; expert interest begins",
    "94% of enterprises using AI; only 14% aiming for enterprise-wide AI by 2025",
    "Consumer-facing generative AI tools emerge; enterprise interest surges",
    "Target year for enterprise-wide AI adoption",
    "Generative AI accelerates workforce automation by a decade",
    "Projected start of 50% work automation",
    "Projected completion of 50% work automation"
]

# Plot setup
plt.figure(figsize=(12, 6))
plt.plot(years, milestone_index, marker='o', color='royalblue', linewidth=2)

# Annotate milestones
for x, y, label in zip(years, milestone_index, milestones):
    wrapped_label = "\n".join(textwrap.wrap(label, width=35))
    plt.text(x, y + 0.2, wrapped_label, fontsize=9, ha='center', va='bottom')

# Economic impact annotation
plt.text(2047, 1, "$2.6–4.4 trillion annual value\n7% global GDP boost", 
         fontsize=10, color='green', ha='right', va='bottom')

# Axis labels and title
plt.title("Enterprise Adoption Curve of Generative AI\nSource: MIT Technology Review Insights", fontsize=14, weight='bold')
plt.xlabel("Year", fontsize=12)
plt.ylabel("Milestone Index", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)

# Display
plt.tight_layout()
plt.show()
# Save the plot as a PNG file
# plt.savefig("enterprise_adoption_curve.png", format='png')

# Set the output path to "/Users/rudolphsurovcik/Library/CloudStorage/GoogleDrive-grs3@lehigh.edu/My Drive/Lehigh Fall 2025/BIS 411 - Fall 2025/Tufte Data"
output_path = "/Users/rudolphsurovcik/Library/CloudStorage/GoogleDrive-grs3@lehigh.edu/My Drive/Lehigh Fall 2025/BIS 411 - Fall 2025/Tufte Data"

#save this file to the output path

plt.savefig(f"{output_path}/enterprise_adoption_curve.png",format='png')

# %%
import matplotlib.pyplot as plt

# Create figure
fig, ax = plt.subplots(figsize=(10, 6))

# Positions for nodes
positions = {
    "User": (0.1, 0.5),
    "Agentic Chatbot": (0.4, 0.5),
    "Multi-Agent System": (0.7, 0.5),
    "Agent A": (0.9, 0.75),
    "Agent B": (0.9, 0.6),
    "Agent C": (0.9, 0.45),
    "Agent D": (0.9, 0.3)
}

# Draw nodes
ax.text(*positions["User"], "👤 User", fontsize=12, ha="center", va="center", bbox=dict(boxstyle="round,pad=0.3", fc="lightblue"))
ax.text(*positions["Agentic Chatbot"], "🤖 Agentic\nChatbot", fontsize=12, ha="center", va="center", bbox=dict(boxstyle="round,pad=0.3", fc="lightgreen"))
ax.text(*positions["Multi-Agent System"], "🤖 Multi-Agent\nSystem", fontsize=12, ha="center", va="center", bbox=dict(boxstyle="round,pad=0.3", fc="khaki"))

# Multi-agent smaller nodes
for agent in ["Agent A", "Agent B", "Agent C", "Agent D"]:
    ax.text(*positions[agent], agent, fontsize=10, ha="center", va="center", bbox=dict(boxstyle="round,pad=0.3", fc="wheat"))

# Draw arrows for single chatbot
ax.annotate("", xy=positions["Agentic Chatbot"], xytext=positions["User"], arrowprops=dict(arrowstyle="->", lw=2))
ax.annotate("", xy=positions["User"], xytext=positions["Agentic Chatbot"], arrowprops=dict(arrowstyle="->", lw=2))

# Draw arrows for multi-agent system
ax.annotate("", xy=positions["Multi-Agent System"], xytext=positions["User"], arrowprops=dict(arrowstyle="->", lw=2))
ax.annotate("", xy=positions["User"], xytext=positions["Multi-Agent System"], arrowprops=dict(arrowstyle="->", lw=2))

# Connect multi-agent system to individual agents
for agent in ["Agent A", "Agent B", "Agent C", "Agent D"]:
    ax.annotate("", xy=positions[agent], xytext=positions["Multi-Agent System"], arrowprops=dict(arrowstyle="->", lw=1))

# Formatting
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axis("off")
ax.set_title("Agentic AI Chatbot vs Multi-Agent System", fontsize=14, weight="bold")

plt.show()

# Set the output path to "/Users/rudolphsurovcik/Library/CloudStorage/GoogleDrive-grs3@lehigh.edu/My Drive/Lehigh Fall 2025/BIS 411 - Fall 2025/Tufte Data"
output_path = "/Users/rudolphsurovcik/Library/CloudStorage/GoogleDrive-grs3@lehigh.edu/My Drive/Lehigh Fall 2025/BIS 411 - Fall 2025/Tufte Data"

#save this file to the output path

plt.savefig(f"{output_path}/MultiAgent Systems.png",format='png')
# Out:
# /Users/rudolphsurovcik/Library/Python/3.13/lib/python/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128100 (\N{BUST IN SILHOUETTE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/rudolphsurovcik/Library/Python/3.13/lib/python/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 129302 (\N{ROBOT FACE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt

# --- Data (illustrative estimates) ---
years = [1990, 2000, 2010, 2020, 2025, 2030]
adoption = [5, 10, 15, 25, 45, 75]  # Estimated percentage adoption

# --- Create the chart ---
plt.figure(figsize=(10, 6))
plt.plot(years, adoption, marker='o', linewidth=2)

# Milestone labels
milestones = {
    1990: "Early MAS research\n(simulations, robotics)",
    2000: "Agent-based modeling in\nacademia & niche industries",
    2010: "Wider use in\nlogistics & traffic systems",
    2020: "LLM rise; agent frameworks emerge",
    2025: "Enterprise pilots:\nfinance, healthcare, supply chain",
    2030: "Mainstream enterprise\nMAS adoption (predicted)"
}

for year, label in milestones.items():
    idx = years.index(year)
    plt.text(year, adoption[idx] + 3, label, ha="center", va="bottom",
             fontsize=9, bbox=dict(boxstyle="round,pad=0.3", fc="lightyellow"))

# --- Formatting ---
plt.title("Timeline of Multi-Agent System (MAS) Adoption", fontsize=14, weight="bold")
plt.xlabel("Year")
plt.ylabel("Estimated Adoption (%)")
plt.ylim(0, 100)
plt.grid(True, linestyle="--", alpha=0.6)

# --- Save a copy ---
outfile = "/Users/rudolphsurovcik/Library/CloudStorage/GoogleDrive-grs3@lehigh.edu/My Drive/Lehigh Fall 2025/BIS 411 - Fall 2025/Tufte Data/MultiAgent Systems Timeline.png"
plt.savefig(outfile, dpi=200, bbox_inches="tight")

plt.show()

# Set the output path to "/Users/rudolphsurovcik/Library/CloudStorage/GoogleDrive-grs3@lehigh.edu/My Drive/Lehigh Fall 2025/BIS 411 - Fall 2025/Tufte Data"
output_path = "/Users/rudolphsurovcik/Library/CloudStorage/GoogleDrive-grs3@lehigh.edu/My Drive/Lehigh Fall 2025/BIS 411 - Fall 2025/Tufte Data"

#save this file to the output path

#plt.savefig(f"{output_path}/MultiAgent Systems Timeline.png",format='png')

# %%
import matplotlib.pyplot as plt
import textwrap

# Stages of AI progression
stages = ["Narrow AI", "Proto-AGI", "AGI"]
capabilities = [20, 50, 100]  # illustrative "capability index"

# Plot progression
plt.figure(figsize=(10, 6))
plt.plot(stages, capabilities, marker="o", linewidth=3, color="teal")

# Annotate descriptions with wrapped text
labels = {
    "Narrow AI": "Specialized, single-task (Spam filter, recommender systems)",
    "Proto-AGI": "Early generalization, tool use, planning, multi-modal reasoning (Current LLM agents)",
    "AGI": "Human-level general intelligence: Adaptive, robust, creative"
}

for stage, cap in zip(stages, capabilities):
    wrapped = "\n".join(textwrap.wrap(labels[stage], width=35))
    plt.text(stage, cap - 10, wrapped, ha="center", fontsize=9,
             bbox=dict(boxstyle="round,pad=0.3", fc="lightyellow"))

# Formatting
plt.title("Progression from Narrow AI → Proto-AGI → AGI", fontsize=14, weight="bold")
plt.ylabel("General Capability (illustrative index)")
plt.ylim(0, 120)
plt.grid(True, linestyle="--", alpha=0.6)

plt.show()

# %%
import matplotlib.pyplot as plt

# Comparison categories
categories = [
    "Knowledge Representation",
    "Learning Method",
    "Biological Inspiration",
    "Strengths",
    "Weaknesses",
    "Feynman's View"
]

# Symbolic AI details
symbolic = [
    "Explicit rules, logic, symbols",
    "Rule-based reasoning\n(no learning, programmed knowledge)",
    "Low — abstract logic, not brain-like",
    "Good at formal logic, proofs,\nstructured domains",
    "Rigid, brittle, hard to scale;\npoor at perception",
    "Skeptical — too rigid,\nnot reflective of real brains"
]

# Neural Networks details
neural = [
    "Distributed weights & activations",
    "Learns from data via training\n(adaptive)",
    "High — inspired by neurons & synapses",
    "Good at perception, pattern\nrecognition, generalization",
    "Opaque, data-hungry, hard to explain",
    "Favored — saw brains as\nparallel networks of elements"
]

# Create figure
fig, ax = plt.subplots(figsize=(12, 6))
ax.axis("off")

# Column titles
# Main title is set below, so add subtitle beneath it
#ax.text(0.5, 0.98, "Symbolic AI and Neural Networks", ha="center", fontsize=12, weight="bold", color="gray")

# Column titles
ax.text(0.40, 0.95, "Symbolic AI", ha="center", fontsize=12, weight="bold", color="darkred")
ax.text(0.85, 0.95, "Neural Networks", ha="center", fontsize=12, weight="bold", color="darkgreen")

# Plot rows
for i, category in enumerate(categories):
    y = 1 - (i+1)*0.13
    ax.text(0.05, y, category, ha="left", fontsize=10, weight="bold")
    ax.text(0.40, y, symbolic[i], ha="center", fontsize=9, bbox=dict(boxstyle="round,pad=0.3", fc="mistyrose"))
    ax.text(0.85, y, neural[i], ha="center", fontsize=9, bbox=dict(boxstyle="round,pad=0.3", fc="honeydew"))

plt.title("Symbolic AI vs Neural Networks", fontsize=14, weight="bold")
plt.show()

# %%
import matplotlib.pyplot as plt

# --- Timeline events (arc of AI) ---
years = [1956, 1980, 1997, 2012, 2022, 2025]
labels = [
    "1956\nSymbolic AI\n(Dartmouth: McCarthy, Minsky, Simon)",
    "1980\nMachine Learning\n(Expert systems, Backpropagation)",
    "1997\nBig Data + Early ML\n(IBM Deep Blue, stats)",
    "2012\nDeep Learning\n(AlexNet: Hinton, Bengio, LeCun)",
    "2022\nGenerative AI\n(ChatGPT, mainstream LLMs)",
    "2025\nProto-AGI\n(Multi‑modal, agentic)"
]

# --- AI Winters (approximate ranges) ---
ai_winters = [
    (1974, 1980, "First AI Winter"),
    (1987, 1993, "Second AI Winter"),
]

# --- Build the figure ---
fig, ax = plt.subplots(figsize=(14, 5))

# Base horizontal timeline
xmin, xmax = min(years) - 5, max(years) + 5
ax.hlines(1, xmin, xmax, color="gray", linewidth=1)

# Shade AI Winters
for start, end, name in ai_winters:
    ax.axvspan(start, end, ymin=0.63, ymax=0.77, color="lightcoral", alpha=0.3)
    ax.text((start + end) / 2, 0.3, name, ha="center", va="center",
            fontsize=9, weight="bold", color="darkred")

# Plot event markers
ax.scatter(years, [1]*len(years), color="teal", s=100, zorder=3)

# Place event labels alternating above/below the line
for i, (yr, text) in enumerate(zip(years, labels)):
    offset = 0.28 if i % 2 == 0 else -0.28
    ax.text(yr, 1 + offset, text, ha="center", va="center",
            fontsize=9, bbox=dict(boxstyle="round,pad=0.3", fc="lightyellow"))

# Formatting
ax.set_xlim(xmin, xmax)
ax.set_ylim(0.2, 1.7)
ax.axis("off")
ax.set_title(
    "Timeline of AI Development with AI Winters\n"
    "Symbolic AI → Machine Learning → Deep Learning → Generative AI → Proto‑AGI",
    fontsize=12, weight="bold"
)

plt.show()

# Save a copy (optional)
# Set the output path to "/Users/rudolphsurovcik/Library/CloudStorage/GoogleDrive-grs3@lehigh.edu/My Drive/Lehigh Fall 2025/BIS 411 - Fall 2025/Tufte Data"
output_path = "/Users/rudolphsurovcik/Library/CloudStorage/GoogleDrive-grs3@lehigh.edu/My Drive/Lehigh Fall 2025/BIS 411 - Fall 2025/Tufte Data"

#save this file to the output path

plt.savefig(f"{output_path}/Timeline.png",format='png')

# %%
import matplotlib.pyplot as plt
# %pip install networkx
import networkx as nx
import matplotlib.patches as mpatches

# Define the PayPal Mafia members and companies
members = [
    "Elon Musk", "Peter Thiel", "Max Levchin", "Reid Hoffman",
    "David Sacks", "Steve Chen", "Chad Hurley", "Jawed Karim",
    "Jeremy Stoppelman", "Roelof Botha", "Keith Rabois"
]

# Companies grouped by industry
companies_by_industry = {
    "Transportation/Space": ["Tesla", "SpaceX", "The Boring Company"],
    "AI/Neurotech": ["Neuralink", "xAI", "Inflection AI", "Palantir"],
    "Fintech": ["Affirm", "Slide", "Square (Block)"],
    "Venture Capital": ["Founders Fund", "Greylock Partners", "Craft Ventures", "Sequoia Capital"],
    "Social Media/Networking": ["LinkedIn", "Facebook", "Yammer"],
    "Video/Media": ["YouTube", "MixBit"],
    "Local/Reviews": ["Yelp"],
    "Delivery/Marketplace": ["DoorDash", "Airbnb"]
}

# Flatten companies list
companies = [c for clist in companies_by_industry.values() for c in clist]

# Relationships (edges) with role type (founded vs funded)
edges = [
    ("Elon Musk", "Tesla", "founded"), ("Elon Musk", "SpaceX", "founded"), ("Elon Musk", "Neuralink", "founded"),
    ("Elon Musk", "The Boring Company", "founded"), ("Elon Musk", "xAI", "founded"),
    ("Peter Thiel", "Palantir", "founded"), ("Peter Thiel", "Founders Fund", "founded"),
    ("Max Levchin", "Affirm", "founded"), ("Max Levchin", "Slide", "founded"),
    ("Reid Hoffman", "LinkedIn", "founded"), ("Reid Hoffman", "Greylock Partners", "funded"), ("Reid Hoffman", "Inflection AI", "founded"),
    ("David Sacks", "Yammer", "founded"), ("David Sacks", "Craft Ventures", "founded"),
    ("Steve Chen", "YouTube", "founded"), ("Chad Hurley", "YouTube", "founded"), ("Jawed Karim", "YouTube", "founded"),
    ("Chad Hurley", "MixBit", "founded"),
    ("Jeremy Stoppelman", "Yelp", "founded"),
    ("Roelof Botha", "Sequoia Capital", "funded"),
    ("Keith Rabois", "DoorDash", "funded"), ("Keith Rabois", "Airbnb", "funded"),
    ("Keith Rabois", "Facebook", "funded"), ("Keith Rabois", "Square (Block)", "funded")
]

# Create bipartite graph
G = nx.DiGraph()
G.add_nodes_from(members, bipartite=0)
G.add_nodes_from(companies, bipartite=1)
for m, c, role in edges:
    if role == "founded":
        G.add_edge(m, c, role="founded")
    else:
        G.add_edge(m, c, role="funded")

# Assign colors by category
industry_colors = {
    "Transportation/Space": "lightcoral",
    "AI/Neurotech": "lightyellow",
    "Fintech": "lightgreen",
    "Venture Capital": "lightpink",
    "Social Media/Networking": "lightskyblue",
    "Video/Media": "plum",
    "Local/Reviews": "khaki",
    "Delivery/Marketplace": "orange"
}

node_colors = []
for node in G.nodes():
    if node in members:
        node_colors.append("lightblue")
    else:
        color = "lightgray"
        for industry, comps in companies_by_industry.items():
            if node in comps:
                color = industry_colors[industry]
                break
        node_colors.append(color)

# Layout for bipartite graph (spread out more vertically)
pos = {}
pos.update((node, (0, i * 2)) for i, node in enumerate(members))  # Left column: members
pos.update((node, (1, i * 1.5)) for i, node in enumerate(companies))  # Right column: companies

# Draw graph
plt.figure(figsize=(26, 22))

# Draw nodes
nx.draw_networkx_nodes(G, pos, node_size=5000, node_color=node_colors)
nx.draw_networkx_labels(G, pos, font_size=12, font_weight="bold")

# Draw edges with different styles
founded_edges = [(u, v) for u, v, d in G.edges(data=True) if d['role'] == "founded"]
funded_edges = [(u, v) for u, v, d in G.edges(data=True) if d['role'] == "funded"]

nx.draw_networkx_edges(G, pos, edgelist=founded_edges, edge_color="black", arrows=True, width=2)
nx.draw_networkx_edges(G, pos, edgelist=funded_edges, edge_color="gray", style="dashed", arrows=True, width=2)

# Legend
legend_patches = [mpatches.Patch(color="lightblue", label="PayPal Mafia Members")]
for industry, color in industry_colors.items():
    legend_patches.append(mpatches.Patch(color=color, label=industry))

edge_legend = [
    mpatches.Patch(color="black", label="Founded (solid)"),
    mpatches.Patch(color="gray", label="Funded (dashed)")
]

plt.legend(handles=legend_patches + edge_legend, loc="upper left", bbox_to_anchor=(1, 1), fontsize=12)

plt.title("The PayPal Mafia and the Companies They Founded or Funded\n(Solid = Founded, Dashed = Funded)", fontsize=18, weight="bold")
plt.axis("off")
plt.show()
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 31.7 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# Categories and values for Generative AI vs. Human Therapist
categories = [
    "Crisis Intervention",
    "Depth of Understanding",
    "Consistency & Availability",
    "Emotional Connection",
    "Ethics & Accountability",
    "Companionship Role",
    "Scalability & Cost",
    "Therapy Quality (Routine, Non-Crisis)",
    "Trust & Safety"
]

# Scores: 1 = very poor, 5 = excellent
ai_scores = [1, 2, 5, 2, 1, 4, 5, 3, 2]
therapist_scores = [5, 5, 3, 5, 5, 3, 2, 5, 5]

# Create bar chart comparison
x = range(len(categories))
width = 0.35

fig, ax = plt.subplots(figsize=(12, 7))

bars1 = ax.bar([i - width/2 for i in x], ai_scores, width, label="Generative AI", alpha=0.7)
bars2 = ax.bar([i + width/2 for i in x], therapist_scores, width, label="PhD-Level Therapist", alpha=0.7)

# Formatting
ax.set_ylabel("Effectiveness Score (1 = Poor, 5 = Excellent)")
ax.set_title("Generative AI vs. Human Therapist (25 yrs exp.)")
ax.set_xticks(x)
ax.set_xticklabels(categories, rotation=45, ha="right")
ax.legend()

plt.tight_layout()
plt.show()

# Redo the chart but make it a horizontal bar chart
# Sort the categories by therapist scores in descending order and difference between AI and therapist scores
# use labeled dots not bars
# Connect the dots with lines between AI and Therapist scores for each category
# (draw a line from ai_scores[i] to therapist_scores[i] at each y position)
# remove the x-axis ticks and labels, but keep the Title
# make Generative AI marks dots and Therapist marks squares
# remove the plot area frame

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.scatter(ai_scores, x, color="royalblue", label="Generative AI", s=120, zorder=3, marker='o')
ax.scatter(therapist_scores, x, color="darkorange", label="PhD-Level Therapist", s=120, zorder=3, marker='s')

ax.set_xticks([])
ax.set_xticklabels([])

sorted_indices = sorted(range(len(therapist_scores)), key=lambda i: (therapist_scores[i], therapist_scores[i] - ai_scores[i]), reverse=True)
categories = [categories[i] for i in sorted_indices]
ai_scores = [ai_scores[i] for i in sorted_indices]
therapist_scores = [therapist_scores[i] for i in sorted_indices]

fig, ax = plt.subplots(figsize=(12, 7))

# Plot dots for AI and Therapist scores
ax.scatter(ai_scores, x, color="royalblue", label="Generative AI", s=120, zorder=3)
ax.scatter(therapist_scores, x, color="darkorange", label="PhD-Level Therapist", s=120, zorder=3)

# Connect the dots with lines
for idx in x:
    ax.plot([ai_scores[idx], therapist_scores[idx]], [idx, idx], color="gray", linestyle="--", linewidth=2, zorder=2)

# Annotate each dot with its score
for i in x:
    ax.text(ai_scores[i] + 0.1, i, str(ai_scores[i]), color="royalblue", fontsize=10, va="top", ha="center")
    ax.text(therapist_scores[i] + 0.1, i, str(therapist_scores[i]), color="darkorange", fontsize=10, va="bottom", ha="center")

# Formatting
ax.set_title("Generative AI vs. Human Therapist (25 yrs exp.)")
ax.set_yticks(list(x))
ax.set_yticklabels(categories)
ax.legend()
ax.set_xlabel("Effectiveness Score (1 = Poor, 5 = Excellent)")
ax.set_xticks([])
ax.set_xticklabels([])

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Timeline data
years = [1977, 1981, 1983, 1984, 1985]
events = [
    "Apple II released\n(popular in homes, schools)",
    "IBM PC launched\n(becomes business standard)",
    "Apple IIe released\n(strong in education, limited in business)",
    "Apple Macintosh launched\n(graphical UI, niche in design/education)",
    "IBM PC Clones emerge\n(Compaq, Dell, etc.; rapid corporate adoption)"
]

# Create figure
plt.figure(figsize=(12, 4))
plt.hlines(1, min(years)-1, max(years)+1, color="gray", linewidth=1)

# Plot events
for i, year in enumerate(years):
    plt.plot(year, 1, "o", markersize=10, color="royalblue")
    plt.text(year, 1.05, str(year), ha="center", fontsize=10, fontweight="bold")
    plt.text(year, 0.8, events[i], ha="center", fontsize=9, wrap=True)

# Style
plt.title("Timeline: Apple II vs. IBM PC in Business Adoption (1977–1985)", fontsize=14, fontweight="bold")
plt.yticks([])
plt.ylim(0.6, 1.3)
plt.xlabel("Year", fontsize=12)
plt.tight_layout()
plt.show()
