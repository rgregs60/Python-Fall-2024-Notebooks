# %% [markdown]
# <div style="background-color: #1f77b4; color: #FFFFE0; padding: 20px; border-radius: 5px; margin-top: 20px; border: 1px solid #b8daff;"
# >
# <h3>Demo Lecture #8: BIS 411 - Storytelling with Data</h3>
# <p>Lecture Topic: Python Demo #8 - Modify or Create a Graph Using Gen AI<p>
# <p>Use Copilot for Github, Chat GPT4, or other Gen AI coding too..<p>
# <p> <p>
# <p>You will then take the one chart you modified and create the one slide 3 Minute Story.<p>
# </div>

# %% [markdown]
# <h5>Import Libraries and Check for Updates:</h5>

# %%
# Check for the latest versions and install if not up to date.
# if you do not need to update a package, you can comment it out by adding a # in front of the line

### Python Version 3.12.6

#%pip install pandas --upgrade
#%pip install numpy --upgrade
#%pip install seaborn --upgrade
#%pip install matplotlib --upgrade
#%pip install jupyter --upgrade
#%pip install statsmodels --upgrade
#%pip install jupyterlab --upgrade
#%pip install ipywidgets --upgrade
#%pip install python --upgrade
#%pip install python-pptx --upgrade
#%pip install pandas --upgrade
#%pip install requests --upgrade
#%pip install openpyxl --upgrade
#%pip install xlrd --upgrade
#%pip install tabulate --upgrade
#%pip install os --upgrade  
#%pip install scipy --upgrade

import os   #importing os library
import pandas as pd     #importing pandas library 
import numpy as np    #importing numpy library 
import seaborn as sns   #importing seaborn library
import matplotlib.pyplot as plt  #importing matplotlib library
import jupyter    #importing jupyter library
import jupyterlab   #importing jupyterlab library
from pptx import Presentation #importing pptx library
from pptx.util import Inches  #importing Inches from pptx.util
import openpyxl #importing openpyxl library
import scipy as stats #importing scipy library
import tabulate #importing tabulate library
import requests #importing requests library
import xlrd #importing xlrd library
import statsmodels #importing statsmodels library
#import statsmodels.api as sm #importing statsmodels.api as sm
#import statsmodels.formula.api as smf #importing statsmodels.formula.api as smf
import statsmodels.stats.api as sms #importing statsmodels.stats.api as sms
import statsmodels.stats.outliers_influence as oi #importing statsmodels.stats.outliers_influence as oi
import statsmodels.stats.diagnostic as dg #importing statsmodels.stats.diagnostic as dg
import statsmodels.stats.stattools as st #importing statsmodels.stats.stattools as st
import statsmodels.stats.power as sp #importing statsmodels.stats.power as sp
import statsmodels.stats.proportion as spp #importing statsmodels.stats.proportion as spp
import statsmodels.stats.weightstats as sw #importing statsmodels.stats.weightstats as sw
import statsmodels.stats.multicomp as smm #importing statsmodels.stats.multicomp as smm
import statsmodels.stats.libqsturng as sl #importing statsmodels.stats.libqsturng as sl
import statsmodels.stats.moment_helpers as sh #importing statsmodels.stats.moment_helpers as sh

# %% [markdown]
# <div style="background-color: #1f77b4; color: #FFFFE0; padding: 20px; border-radius: 25px; margin-top: 30px; border: 1px solid #b8daff;"
# >
# <p>Creating Data Frame Sat_Data loading the data Directly into Python<p>
# </div>

# %%
### I usually reset the kernel after importing all the libraries to make sure that the libraries are loaded correctly and Import the Data Set

# %reset -f 

import pandas as pd
from io import StringIO

# The text data provided by the user
data = """Testing_Wave,Performance,Ease_of_Use,Maintenance
1,6,5,7
1,4,4,4
1,2,3,6
1,5,5,6
1,4,3,5
1,5,2,2
1,6,6,5
1,6,5,6
1,5,5,6
1,4,3,7
1,7,5,4
1,1,1,1
1,6,5,6
1,4,5,6
1,6,5,7
1,5,5,5
1,5,3,6
1,5,5,6
1,5,5,6
1,7,7,7
1,6,5,6
1,6,6,7
1,6,6,6
1,7,7,7
1,6,5,7
1,4,3,4
1,6,5,6
1,5,5,6
1,5,5,6
1,5,5,6
1,7,5,1
2,6,6,6
2,5,6,6
2,6,6,6
2,6,6,6
2,5,3,5
2,1,1,5
2,5,4,7
2,5,5,5
2,6,6,7
2,6,5,6
2,7,7,7
2,5,5,6
2,6,6,6
2,7,6,7
2,6,6,6
2,6,5,7
2,5,5,5
2,5,5,6
2,3,3,5
2,4,2,7
2,6,5,7
2,6,5,7
2,6,4,7
2,5,5,6
2,5,5,6
2,6,6,7
2,5,5,6
2,6,5,3
2,3,3,6
2,1,1,5
2,5,5,7
2,6,5,7
2,5,5,5
2,6,6,7
2,4,4,4
3,7,6,7
3,6,6,7
3,2,2,6
3,5,5,5
3,7,7,7
3,5,5,6
3,5,5,5
3,5,5,6
3,6,5,6
3,5,5,7
3,4,4,4
3,6,6,7
3,5,5,6
3,6,5,7
3,5,5,6
3,1,2,1
3,5,5,5
3,6,6,6
3,6,6,6
3,5,5,5
3,6,6,7
3,4,3,6
3,6,6,7
3,5,5,6
3,7,7,7
3,5,5,5
3,6,6,6"""

# Use StringIO to simulate reading from a file
data_io = StringIO(data)

# Create the DataFrame
Sat_Data = pd.read_csv(data_io)

### I usually make a copy of the data after I import a data so that I can always go back to the original data if I need to.

Sat_Data_Num = Sat_Data.copy()
Sat_Data_Clean = Sat_Data.copy()

# %% [markdown]
# ```markdown
#
# Copilot for Github Prompt: "Display a Data Dictionary of Sat_Data"
#
# ### Data Dictionary for `Sat_Data`
#
# | Column Name    | Data Type | Description                                      |
# |----------------|-----------|--------------------------------------------------|
# | Testing_Wave   | int64     | The wave of testing, indicating different phases |
# | Performance    | int64     | Performance score                                |
# | Ease_of_Use    | int64     | Ease of use score                                |
# | Maintenance    | int64     | Maintenance score                                |
#
#
# ```

# %%
### Adding Data Labels to Performance, Ease_of_Use, and Maintenance Columns

### Copilot Prompt: "Add data labels to the Performance, Ease_of_Use, and Maintenance columns in the DataFrame Sat_Data. 

#The labels should be descriptive and correspond to the numerical values in the columns.

# Define the mapping for the labels
labels = {
    1: '1-Strongly Disagree',
    2: '2-Disagree',
    3: '3-Somewhat Disagree',
    4: '4-Neither Agree nor Disagree',
    5: '5-Somewhat Agree',
    6: '6-Agree',
    7: '7-Strongly Agree'
}

# Apply the mapping to the specified columns
Sat_Data[['Performance', 'Ease_of_Use', 'Maintenance']] = Sat_Data[['Performance', 'Ease_of_Use', 'Maintenance']].replace(labels)

Sat_Data_Labels = Sat_Data.copy() # Assign the modified DataFrame to a new variable to save for later use

# %% [markdown]
# <div style="background-color: #1f77b4; color: #FFFFE0; padding: 20px; border-radius: 5px; margin-top: 20px; border: 1px solid #b8daff;">
# <p>Create a Frequency Table for all the variables<p>
# <p>and a Summary Tables of Mean, Median, and Sd for Performance', 'Ease_of_Use', 'Maintenance"<p>
# </div>

# %%
# Create a frequency table for each of the variables in the Sat_Data DataFrame

### Copilot Prompt: "Create a frequency table for each of the variables in the Sat_Data DataFrame order by Value

# Create a frequency table for each of the variables in the Sat_Data DataFrame ordered by value
frequency_tables = {}
for column in Sat_Data.columns:
    frequency_tables[column] = Sat_Data[column].value_counts().sort_index()

# Display the frequency tables
for column, table in frequency_tables.items():
    print(f"Frequency table for {column}:\n{table}\n")
# Out:
# Frequency table for Testing_Wave:
# Testing_Wave
# 1    31
# 2    35
# 3    27
# Name: count, dtype: int64
#
# Frequency table for Performance:
# Performance
# 1-Strongly Disagree              4
# 2-Disagree                       2
# 3-Somewhat Disagree              2
# 4-Neither Agree nor Disagree     9
# 5-Somewhat Agree                33
# 6-Agree                         34
# 7-Strongly Agree                 9
# Name: count, dtype: int64
#
# Frequency table for Ease_of_Use:
# Ease_of_Use
# 1-Strongly Disagree              3
# 2-Disagree                       4
# 3-Somewhat Disagree              9
# 4-Neither Agree nor Disagree     5
# 5-Somewhat Agree                46
# 6-Agree                         21
# 7-Strongly Agree                 5
# Name: count, dtype: int64
#
# Frequency table for Maintenance:
# Maintenance
# 1-Strongly Disagree              3
# 2-Disagree                       1
# 3-Somewhat Disagree              1
# 4-Neither Agree nor Disagree     5
# ...

# %% [markdown]
# This code snippet creates and displays frequency tables for each variable in the [`Sat_Data`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X46sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A6%2C%22character%22%3A14%7D%7D%5D%2C%222e6a17dc-3aae-42da-88ec-40ca7249836f%22%5D "Go to definition") DataFrame. A frequency table shows the count of unique values for a given variable, which helps in understanding the distribution of data.
#
# 1. **Initialize an Empty Dictionary**:
#    ```python
#    frequency_tables = {}
#    ```
#    - An empty dictionary named [`frequency_tables`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X46sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A5%2C%22character%22%3A0%7D%7D%5D%2C%222e6a17dc-3aae-42da-88ec-40ca7249836f%22%5D "Go to definition") is initialized to store the frequency tables for each column in the [`Sat_Data`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X46sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A6%2C%22character%22%3A14%7D%7D%5D%2C%222e6a17dc-3aae-42da-88ec-40ca7249836f%22%5D "Go to definition") DataFrame.
#
# 2. **Create Frequency Tables**:
#    ```python
#    for column in Sat_Data.columns:
#        frequency_tables[column] = Sat_Data[column].value_counts().sort_index()
#    ```
#    - The code iterates over each column in the [`Sat_Data`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X46sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A6%2C%22character%22%3A14%7D%7D%5D%2C%222e6a17dc-3aae-42da-88ec-40ca7249836f%22%5D "Go to definition") DataFrame using a [`for`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X46sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A0%2C%22character%22%3A27%7D%7D%5D%2C%222e6a17dc-3aae-42da-88ec-40ca7249836f%22%5D "Go to definition") loop.
#    - For each column, it calculates the frequency of unique values using the [`value_counts()`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X46sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A7%2C%22character%22%3A48%7D%7D%5D%2C%222e6a17dc-3aae-42da-88ec-40ca7249836f%22%5D "Go to definition") method.
#    - The [`sort_index()`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X46sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A7%2C%22character%22%3A63%7D%7D%5D%2C%222e6a17dc-3aae-42da-88ec-40ca7249836f%22%5D "Go to definition") method is called to sort the frequency table by the unique values in ascending order.
#    - The resulting frequency table is stored in the [`frequency_tables`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X46sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A5%2C%22character%22%3A0%7D%7D%5D%2C%222e6a17dc-3aae-42da-88ec-40ca7249836f%22%5D "Go to definition") dictionary with the column name as the key.
#
# 3. **Display Frequency Tables**:
#    ```python
#    for column, table in frequency_tables.items():
#        print(f"Frequency table for {column}:\n{table}\n")
#    ```
#    - The code iterates over the [`frequency_tables`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X46sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A5%2C%22character%22%3A0%7D%7D%5D%2C%222e6a17dc-3aae-42da-88ec-40ca7249836f%22%5D "Go to definition") dictionary using another [`for`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X46sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A0%2C%22character%22%3A27%7D%7D%5D%2C%222e6a17dc-3aae-42da-88ec-40ca7249836f%22%5D "Go to definition") loop.
#    - For each column and its corresponding frequency table, it prints the frequency table to the console.
#    - The [`print`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X46sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A11%2C%22character%22%3A4%7D%7D%5D%2C%222e6a17dc-3aae-42da-88ec-40ca7249836f%22%5D "Go to definition") function is used to display the column name and its frequency table in a readable format, with each table separated by a newline for clarity.
#
# This approach provides a clear and organized way to examine the distribution of values for each variable in the [`Sat_Data`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X46sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A6%2C%22character%22%3A14%7D%7D%5D%2C%222e6a17dc-3aae-42da-88ec-40ca7249836f%22%5D "Go to definition") DataFrame, making it easier to identify patterns and anomalies in the data.

# %% [markdown]
# The provided code snippet creates and displays frequency tables for each variable in the [`Sat_Data`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X46sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A6%2C%22character%22%3A14%7D%7D%5D%2C%22d9948fa2-18b7-48ee-85af-3c5bc717b395%22%5D "Go to definition") DataFrame. A frequency table shows the count of unique values for a given variable, which is useful for understanding the distribution of data.
#
# First, the script initializes an empty dictionary named [`frequency_tables`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X46sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A5%2C%22character%22%3A0%7D%7D%5D%2C%22d9948fa2-18b7-48ee-85af-3c5bc717b395%22%5D "Go to definition") to store the frequency tables for each column in the [`Sat_Data`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X46sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A6%2C%22character%22%3A14%7D%7D%5D%2C%22d9948fa2-18b7-48ee-85af-3c5bc717b395%22%5D "Go to definition") DataFrame. It then iterates over each column in the DataFrame using a [`for`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X46sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A0%2C%22character%22%3A27%7D%7D%5D%2C%22d9948fa2-18b7-48ee-85af-3c5bc717b395%22%5D "Go to definition") loop. For each column, the script calculates the frequency of unique values using the [`value_counts`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22file%22%2C%22authority%22%3A%22%22%2C%22path%22%3A%22%2FLibrary%2FFrameworks%2FPython.framework%2FVersions%2F3.12%2Flib%2Fpython3.12%2Fsite-packages%2Fpandas%2Fcore%2Fbase.py%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22%22%7D%2C%22pos%22%3A%7B%22line%22%3A923%2C%22character%22%3A8%7D%7D%2C%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X46sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A7%2C%22character%22%3A48%7D%7D%5D%2C%22d9948fa2-18b7-48ee-85af-3c5bc717b395%22%5D "Go to definition") method. The [`value_counts`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22file%22%2C%22authority%22%3A%22%22%2C%22path%22%3A%22%2FLibrary%2FFrameworks%2FPython.framework%2FVersions%2F3.12%2Flib%2Fpython3.12%2Fsite-packages%2Fpandas%2Fcore%2Fbase.py%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22%22%7D%2C%22pos%22%3A%7B%22line%22%3A923%2C%22character%22%3A8%7D%7D%2C%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X46sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A7%2C%22character%22%3A48%7D%7D%5D%2C%22d9948fa2-18b7-48ee-85af-3c5bc717b395%22%5D "Go to definition") method returns a Series containing counts of unique values, sorted by the values themselves when the [`sort_index`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22file%22%2C%22authority%22%3A%22%22%2C%22path%22%3A%22%2FLibrary%2FFrameworks%2FPython.framework%2FVersions%2F3.12%2Flib%2Fpython3.12%2Fsite-packages%2Fpandas%2Fcore%2Fseries.py%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22%22%7D%2C%22pos%22%3A%7B%22line%22%3A3888%2C%22character%22%3A8%7D%7D%2C%7B%22uri%22%3A%7B%22scheme%22%3A%22file%22%2C%22authority%22%3A%22%22%2C%22path%22%3A%22%2FLibrary%2FFrameworks%2FPython.framework%2FVersions%2F3.12%2Flib%2Fpython3.12%2Fsite-packages%2Fpandas%2Fcore%2Fseries.py%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22%22%7D%2C%22pos%22%3A%7B%22line%22%3A3904%2C%22character%22%3A8%7D%7D%2C%7B%22uri%22%3A%7B%22scheme%22%3A%22file%22%2C%22authority%22%3A%22%22%2C%22path%22%3A%22%2FLibrary%2FFrameworks%2FPython.framework%2FVersions%2F3.12%2Flib%2Fpython3.12%2Fsite-packages%2Fpandas%2Fcore%2Fseries.py%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22%22%7D%2C%22pos%22%3A%7B%22line%22%3A3920%2C%22character%22%3A8%7D%7D%2C%7B%22uri%22%3A%7B%22scheme%22%3A%22file%22%2C%22authority%22%3A%22%22%2C%22path%22%3A%22%2FLibrary%2FFrameworks%2FPython.framework%2FVersions%2F3.12%2Flib%2Fpython3.12%2Fsite-packages%2Fpandas%2Fcore%2Fseries.py%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22%22%7D%2C%22pos%22%3A%7B%22line%22%3A3935%2C%22character%22%3A8%7D%7D%2C%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X46sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A7%2C%22character%22%3A63%7D%7D%5D%2C%22d9948fa2-18b7-48ee-85af-3c5bc717b395%22%5D "Go to definition") method is called. This ensures that the frequency table is ordered by the unique values in ascending order.
#
# After creating the frequency tables, the script iterates over the [`frequency_tables`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X46sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A5%2C%22character%22%3A0%7D%7D%5D%2C%22d9948fa2-18b7-48ee-85af-3c5bc717b395%22%5D "Go to definition") dictionary using another [`for`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X46sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A0%2C%22character%22%3A27%7D%7D%5D%2C%22d9948fa2-18b7-48ee-85af-3c5bc717b395%22%5D "Go to definition") loop. For each column and its corresponding frequency table, the script prints the frequency table to the console. The [`print`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X46sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A11%2C%22character%22%3A4%7D%7D%2C%7B%22uri%22%3A%7B%22scheme%22%3A%22file%22%2C%22authority%22%3A%22%22%2C%22path%22%3A%22%2FUsers%2Frgregs%2F.vscode%2Fextensions%2Fms-python.vscode-pylance-2024.9.2%2Fdist%2Ftypeshed-fallback%2Fstdlib%2Fbuiltins.pyi%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22%22%7D%2C%22pos%22%3A%7B%22line%22%3A1631%2C%22character%22%3A4%7D%7D%2C%7B%22uri%22%3A%7B%22scheme%22%3A%22file%22%2C%22authority%22%3A%22%22%2C%22path%22%3A%22%2FUsers%2Frgregs%2F.vscode%2Fextensions%2Fms-python.vscode-pylance-2024.9.2%2Fdist%2Ftypeshed-fallback%2Fstdlib%2Fbuiltins.pyi%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22%22%7D%2C%22pos%22%3A%7B%22line%22%3A1639%2C%22character%22%3A4%7D%7D%5D%2C%22d9948fa2-18b7-48ee-85af-3c5bc717b395%22%5D "Go to definition") function is used to display the column name and its frequency table in a readable format, with each table separated by a newline for clarity.
#
# This approach provides a clear and organized way to examine the distribution of values for each variable in the [`Sat_Data`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X46sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A6%2C%22character%22%3A14%7D%7D%5D%2C%22d9948fa2-18b7-48ee-85af-3c5bc717b395%22%5D "Go to definition") DataFrame, making it easier to identify patterns and anomalies in the data.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the style of the visualization
sns.set(style="whitegrid")

# List of columns to plot
columns_to_plot = ['Performance', 'Ease_of_Use', 'Maintenance']

# Create a figure with subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 10))

# Plot histograms with normal curves for each column
for ax, column in zip(axes, columns_to_plot):
    sns.histplot(Sat_Data_Clean[column], bins=7, kde=True, ax=ax)
    ax.set_title(f'Histogram of {column}')
    ax.set_xlabel(column)
    ax.set_ylabel('Frequency')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# The provided code snippet is a Python script that utilizes the Seaborn and Matplotlib libraries to create visualizations of data. The script begins by importing the necessary libraries: [`seaborn`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y142sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A0%2C%22character%22%3A7%7D%7D%5D%2C%2230e0148e-b77f-442b-9210-cff11e1da813%22%5D "Go to definition") (aliased as [`sns`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y142sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A0%2C%22character%22%3A18%7D%7D%5D%2C%2230e0148e-b77f-442b-9210-cff11e1da813%22%5D "Go to definition")) for statistical data visualization and [`matplotlib.pyplot`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y142sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A1%2C%22character%22%3A7%7D%7D%5D%2C%2230e0148e-b77f-442b-9210-cff11e1da813%22%5D "Go to definition") (aliased as [`plt`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y142sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A1%2C%22character%22%3A28%7D%7D%5D%2C%2230e0148e-b77f-442b-9210-cff11e1da813%22%5D "Go to definition")) for creating plots.
#
# The visualization style is set using [`sns.set(style="whitegrid")`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y142sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A0%2C%22character%22%3A18%7D%7D%5D%2C%2230e0148e-b77f-442b-9210-cff11e1da813%22%5D "Go to definition"), which applies a white grid background to all subsequent plots, enhancing readability and aesthetics.
#
# A list named [`columns_to_plot`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y142sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A7%2C%22character%22%3A0%7D%7D%5D%2C%2230e0148e-b77f-442b-9210-cff11e1da813%22%5D "Go to definition") is defined, containing the names of the columns to be visualized: 'Performance', 'Ease_of_Use', and 'Maintenance'. These columns are presumably part of a DataFrame named [`Sat_Data_Clean`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y142sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A14%2C%22character%22%3A17%7D%7D%5D%2C%2230e0148e-b77f-442b-9210-cff11e1da813%22%5D "Go to definition").
#
# A figure with three subplots arranged in a single row is created using [`plt.subplots(1, 3, figsize=(18, 5))`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y142sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A1%2C%22character%22%3A28%7D%7D%5D%2C%2230e0148e-b77f-442b-9210-cff11e1da813%22%5D "Go to definition"). This function returns a figure object ([`fig`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y142sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A10%2C%22character%22%3A0%7D%7D%5D%2C%2230e0148e-b77f-442b-9210-cff11e1da813%22%5D "Go to definition")) and an array of axes objects ([`axes`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y142sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A10%2C%22character%22%3A5%7D%7D%5D%2C%2230e0148e-b77f-442b-9210-cff11e1da813%22%5D "Go to definition")), which are used to plot individual histograms.
#
# The script then iterates over the axes and corresponding column names using a [`for`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y142sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A12%2C%22character%22%3A37%7D%7D%5D%2C%2230e0148e-b77f-442b-9210-cff11e1da813%22%5D "Go to definition") loop. Within each iteration, a histogram with a kernel density estimate (KDE) is plotted for the current column using [`sns.histplot()`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y142sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A0%2C%22character%22%3A18%7D%7D%5D%2C%2230e0148e-b77f-442b-9210-cff11e1da813%22%5D "Go to definition"). The [`bins=7`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y142sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A14%2C%22character%22%3A41%7D%7D%5D%2C%2230e0148e-b77f-442b-9210-cff11e1da813%22%5D "Go to definition") argument specifies the number of bins in the histogram, and [`kde=True`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y142sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A14%2C%22character%22%3A49%7D%7D%5D%2C%2230e0148e-b77f-442b-9210-cff11e1da813%22%5D "Go to definition") adds a KDE curve to the plot. The [`ax=ax`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y142sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A13%2C%22character%22%3A4%7D%7D%5D%2C%2230e0148e-b77f-442b-9210-cff11e1da813%22%5D "Go to definition") argument ensures that each histogram is plotted on the correct subplot.
#
# Each subplot is customized with a title, x-axis label, and y-axis label using [`ax.set_title()`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y142sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A13%2C%22character%22%3A4%7D%7D%5D%2C%2230e0148e-b77f-442b-9210-cff11e1da813%22%5D "Go to definition"), [`ax.set_xlabel()`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y142sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A13%2C%22character%22%3A4%7D%7D%5D%2C%2230e0148e-b77f-442b-9210-cff11e1da813%22%5D "Go to definition"), and [`ax.set_ylabel()`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y142sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A13%2C%22character%22%3A4%7D%7D%5D%2C%2230e0148e-b77f-442b-9210-cff11e1da813%22%5D "Go to definition"), respectively. The titles and labels are dynamically generated based on the column names.
#
# Finally, [`plt.tight_layout()`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y142sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A1%2C%22character%22%3A28%7D%7D%5D%2C%2230e0148e-b77f-442b-9210-cff11e1da813%22%5D "Go to definition") is called to adjust the layout of the subplots, ensuring that they fit neatly within the figure without overlapping. The [`plt.show()`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y142sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A1%2C%22character%22%3A28%7D%7D%5D%2C%2230e0148e-b77f-442b-9210-cff11e1da813%22%5D "Go to definition") function is then called to display the figure with the histograms.
#
# This script effectively visualizes the distribution of data in the specified columns, providing insights into their frequency distributions and underlying patterns.

# %% [markdown]
# <div style="background-color: #1f77b4; color: #FFFFE0; padding: 20px; border-radius: 5px; margin-top: 20px; border: 1px solid #b8daff;">
# <p>Explanation of Code<p>
# </div>

# %% [markdown]
# The provided code snippet creates and displays frequency tables for each column in the DataFrame [`Sat_Data`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X11sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A7%2C%22character%22%3A14%7D%7D%5D%2C%22c8f4e805-1934-424c-8281-a32817687a32%22%5D "Go to definition"). A frequency table shows the count of unique values in a column, which can be useful for understanding the distribution of data.
#
# First, an empty dictionary named [`frequency_tables`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X11sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A5%2C%22character%22%3A0%7D%7D%5D%2C%22c8f4e805-1934-424c-8281-a32817687a32%22%5D "Go to definition") is initialized. This dictionary will store the frequency tables for each column in [`Sat_Data`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X11sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A7%2C%22character%22%3A14%7D%7D%5D%2C%22c8f4e805-1934-424c-8281-a32817687a32%22%5D "Go to definition"). The code then iterates over each column in the DataFrame using a [`for`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X11sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A4%2C%22character%22%3A27%7D%7D%5D%2C%22c8f4e805-1934-424c-8281-a32817687a32%22%5D "Go to definition") loop. For each column, the [`value_counts()`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22file%22%2C%22authority%22%3A%22%22%2C%22path%22%3A%22%2FLibrary%2FFrameworks%2FPython.framework%2FVersions%2F3.12%2Flib%2Fpython3.12%2Fsite-packages%2Fpandas%2Fcore%2Fbase.py%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22%22%7D%2C%22pos%22%3A%7B%22line%22%3A923%2C%22character%22%3A8%7D%7D%2C%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X11sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A8%2C%22character%22%3A48%7D%7D%5D%2C%22c8f4e805-1934-424c-8281-a32817687a32%22%5D "Go to definition") method is called, which returns a Series containing counts of unique values in that column. The [`sort_index()`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22file%22%2C%22authority%22%3A%22%22%2C%22path%22%3A%22%2FLibrary%2FFrameworks%2FPython.framework%2FVersions%2F3.12%2Flib%2Fpython3.12%2Fsite-packages%2Fpandas%2Fcore%2Fseries.py%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22%22%7D%2C%22pos%22%3A%7B%22line%22%3A3888%2C%22character%22%3A8%7D%7D%2C%7B%22uri%22%3A%7B%22scheme%22%3A%22file%22%2C%22authority%22%3A%22%22%2C%22path%22%3A%22%2FLibrary%2FFrameworks%2FPython.framework%2FVersions%2F3.12%2Flib%2Fpython3.12%2Fsite-packages%2Fpandas%2Fcore%2Fseries.py%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22%22%7D%2C%22pos%22%3A%7B%22line%22%3A3904%2C%22character%22%3A8%7D%7D%2C%7B%22uri%22%3A%7B%22scheme%22%3A%22file%22%2C%22authority%22%3A%22%22%2C%22path%22%3A%22%2FLibrary%2FFrameworks%2FPython.framework%2FVersions%2F3.12%2Flib%2Fpython3.12%2Fsite-packages%2Fpandas%2Fcore%2Fseries.py%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22%22%7D%2C%22pos%22%3A%7B%22line%22%3A3920%2C%22character%22%3A8%7D%7D%2C%7B%22uri%22%3A%7B%22scheme%22%3A%22file%22%2C%22authority%22%3A%22%22%2C%22path%22%3A%22%2FLibrary%2FFrameworks%2FPython.framework%2FVersions%2F3.12%2Flib%2Fpython3.12%2Fsite-packages%2Fpandas%2Fcore%2Fseries.py%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22%22%7D%2C%22pos%22%3A%7B%22line%22%3A3935%2C%22character%22%3A8%7D%7D%2C%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X11sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A8%2C%22character%22%3A63%7D%7D%5D%2C%22c8f4e805-1934-424c-8281-a32817687a32%22%5D "Go to definition") method is then called on this Series to sort the counts by the index (i.e., the unique values) in ascending order. The resulting sorted Series is stored in the [`frequency_tables`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X11sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A5%2C%22character%22%3A0%7D%7D%5D%2C%22c8f4e805-1934-424c-8281-a32817687a32%22%5D "Go to definition") dictionary with the column name as the key.
#
# After creating the frequency tables, the code iterates over the [`frequency_tables`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X11sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A5%2C%22character%22%3A0%7D%7D%5D%2C%22c8f4e805-1934-424c-8281-a32817687a32%22%5D "Go to definition") dictionary using another [`for`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X11sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A4%2C%22character%22%3A27%7D%7D%5D%2C%22c8f4e805-1934-424c-8281-a32817687a32%22%5D "Go to definition") loop. For each entry in the dictionary, it prints the column name and the corresponding frequency table. The [`print()`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X11sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A12%2C%22character%22%3A4%7D%7D%2C%7B%22uri%22%3A%7B%22scheme%22%3A%22file%22%2C%22authority%22%3A%22%22%2C%22path%22%3A%22%2FUsers%2Frgregs%2F.vscode%2Fextensions%2Fms-python.vscode-pylance-2024.9.2%2Fdist%2Ftypeshed-fallback%2Fstdlib%2Fbuiltins.pyi%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22%22%7D%2C%22pos%22%3A%7B%22line%22%3A1631%2C%22character%22%3A4%7D%7D%2C%7B%22uri%22%3A%7B%22scheme%22%3A%22file%22%2C%22authority%22%3A%22%22%2C%22path%22%3A%22%2FUsers%2Frgregs%2F.vscode%2Fextensions%2Fms-python.vscode-pylance-2024.9.2%2Fdist%2Ftypeshed-fallback%2Fstdlib%2Fbuiltins.pyi%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22%22%7D%2C%22pos%22%3A%7B%22line%22%3A1639%2C%22character%22%3A4%7D%7D%5D%2C%22c8f4e805-1934-424c-8281-a32817687a32%22%5D "Go to definition") function is used to display the frequency table in a readable format, with each table separated by a newline for clarity.
#
# This approach provides a comprehensive view of the distribution of values in each column of the [`Sat_Data`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X11sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A7%2C%22character%22%3A14%7D%7D%5D%2C%22c8f4e805-1934-424c-8281-a32817687a32%22%5D "Go to definition") DataFrame, making it easier to analyze and understand the data.

# %% [markdown]
# <div style="background-color: #1f77b4; color: #FFFFE0; padding: 20px; border-radius: 5px; margin-top: 20px; border: 1px solid #b8daff;">
# <p>Scroll thru the Data Carefully Make sure that the Data was read correctly<p>
# <p><p>
# <p>You will need to click 'View as a scrollable element to view all of the Output<p>
# <p><p>
# <p>We will next produce a summary table of the mean, median, and sd for the measures<p>
# </div>

# %%
## Display a Summary Table of the Mean, Median, and Standard Deviation for Performance, Ease_of_Use, and Maintenance using the Sat_Data_Num DataFrame

import numpy as np

### Copilot Prompt: "Calculate the mean, median, and standard deviation for the 'Performance', 'Ease_of_Use', and 'Maintenance' columns in the DataFrame Sat_Data_Num 
summary_stats = Sat_Data_Num[['Performance', 'Ease_of_Use', 'Maintenance']].agg(['mean', 'median', 'std'])
print(summary_stats)
# Out:
#         Performance  Ease_of_Use  Maintenance
# mean       5.182796     4.827957     5.806452
# median     5.000000     5.000000     6.000000
# std        1.342825     1.332076     1.320886

# %% [markdown]
# <div style="background-color: #1f77b4; color: #FFFFE0; padding: 20px; border-radius: 5px; margin-top: 20px; border: 1px solid #b8daff;">
# <p>Examine carefully these summary results for any implications they may have on your analysis<p>
# </div>

# %% [markdown]
# <div style="background-color: #1f77b4; color: #FFFFE0; padding: 20px; border-radius: 5px; margin-top: 20px; border: 1px solid #b8daff;">
# <p>Create a Graph of Means by Variable<p>
# <p>Copilot Prompt to Create Graph: "Create Bar Graph of Means including Performance, Ease_of_Use, Maintenance"<p>
# </div>

# %%
# Check the versions of the libraries and load
import pandas as pd  #importing pandas library
import numpy as np  #importing numpy library

Sat_Data = Sat_Data_Clean.copy()

import matplotlib.pyplot as plt  # importing matplotlib library

# Convert the categorical columns back to numerical for calculation

# reverse_labels = {v: k for k, v in labels.items()}

#Sat_Data[['Performance', 'Ease_of_Use', 'Maintenance']] = Sat_Data[['Performance', 'Ease_of_Use', 'Maintenance']].replace(reverse_labels)


# remove Wave from the Bar Graph of Means

mean_values = Sat_Data.drop('Testing_Wave', axis=1).mean()

# Create a bar graph of the mean values - Remove Wave
mean_values.plot(kind='bar', color=['blue', 'green', 'red'])
plt.xlabel('Variables')
plt.ylabel('Mean Values')
plt.title('Mean Values of Performance, Ease of Use, and Maintenance')
plt.show()

# Create a cluster bar graph using waves and show the means

# Create a cluster bar graph using waves and show the means

### Copilot Prompt: "Create a cluster bar graph using the 'Testing_Wave' column to show the means of 'Performance', 'Ease_of_Use', and 'Maintenance' variables

# Calculate the mean values for each Testing_Wave
mean_values_by_wave = Sat_Data.groupby('Testing_Wave')[['Performance', 'Ease_of_Use', 'Maintenance']].mean()

# Plot the cluster bar graph
mean_values_by_wave.plot(kind='bar', figsize=(10, 6))
plt.xlabel('Testing Wave')
plt.ylabel('Mean Values')
plt.title('Mean Performance, Ease of Use, and Maintenance by Testing Wave')
plt.legend(title='Variables')
plt.show()

# %%
# Cluster Bar Graph Mean Values by Testing Wave

Sat_Data = Sat_Data_Clean.copy()

# Now, calculating the mean values
mean_values_updated = Sat_Data.groupby('Testing_Wave').mean()   # Group by Testing Wave and calculate the mean

# Create a larger figure with increased size
fig, ax = plt.subplots(figsize=(14, 8))  # Increased size (width, height)

# Transpose the mean_values dataframe so that variables (Performance, Ease_of_Use, Maintenance) are the x-axis labels
mean_values_updated[['Performance', 'Ease_of_Use', 'Maintenance']].T.plot(kind='bar', ax=ax)

# Set labels and title
ax.set_xlabel('Variable')
ax.set_ylabel('Mean Values')
ax.set_title('Mean Performance, Ease of Use, and Maintenance by Testing Wave')

# Display the plot
plt.xticks(rotation=0)

plt.show()

# %% [markdown]
# <div style="background-color: #1f77b4; color: #FFFFE0; padding: 20px; border-radius: 5px; margin-top: 20px; border: 1px solid #b8daff;">
# <p>Code Explanation<p>
# </div>

# %% [markdown]
# The provided code snippet is a Python script that generates a clustered bar graph to visualize the mean values of certain variables by testing wave. The script begins by creating a copy of the [`Sat_Data_Clean`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y102sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A2%2C%22character%22%3A11%7D%7D%5D%2C%221439b749-8042-4d58-95f7-8178933abf00%22%5D "Go to definition") DataFrame and assigns it to [`Sat_Data`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y102sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A2%2C%22character%22%3A0%7D%7D%5D%2C%221439b749-8042-4d58-95f7-8178933abf00%22%5D "Go to definition"). This ensures that any modifications made to [`Sat_Data`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y102sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A2%2C%22character%22%3A0%7D%7D%5D%2C%221439b749-8042-4d58-95f7-8178933abf00%22%5D "Go to definition") do not affect the original [`Sat_Data_Clean`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y102sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A2%2C%22character%22%3A11%7D%7D%5D%2C%221439b749-8042-4d58-95f7-8178933abf00%22%5D "Go to definition") DataFrame.
#
# Next, the script calculates the mean values of the variables grouped by the 'Testing_Wave' column. This is achieved using the [`groupby`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22file%22%2C%22authority%22%3A%22%22%2C%22path%22%3A%22%2FLibrary%2FFrameworks%2FPython.framework%2FVersions%2F3.12%2Flib%2Fpython3.12%2Fsite-packages%2Fpandas%2Fcore%2Fframe.py%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22%22%7D%2C%22pos%22%3A%7B%22line%22%3A9147%2C%22character%22%3A8%7D%7D%2C%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y102sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A5%2C%22character%22%3A31%7D%7D%5D%2C%221439b749-8042-4d58-95f7-8178933abf00%22%5D "Go to definition") method followed by the [`mean`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22file%22%2C%22authority%22%3A%22%22%2C%22path%22%3A%22%2FLibrary%2FFrameworks%2FPython.framework%2FVersions%2F3.12%2Flib%2Fpython3.12%2Fsite-packages%2Fpandas%2Fcore%2Fgroupby%2Fgroupby.py%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22%22%7D%2C%22pos%22%3A%7B%22line%22%3A2367%2C%22character%22%3A8%7D%7D%2C%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y102sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A5%2C%22character%22%3A55%7D%7D%5D%2C%221439b749-8042-4d58-95f7-8178933abf00%22%5D "Go to definition") method. The resulting DataFrame, [`mean_values_updated`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y102sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A5%2C%22character%22%3A0%7D%7D%5D%2C%221439b749-8042-4d58-95f7-8178933abf00%22%5D "Go to definition"), contains the mean values of each variable for each testing wave.
#
# To create the bar graph, the script sets up a larger figure with dimensions 14 inches by 8 inches using the [`plt.subplots`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y102sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A8%2C%22character%22%3A10%7D%7D%5D%2C%221439b749-8042-4d58-95f7-8178933abf00%22%5D "Go to definition") function. This larger figure size ensures that the graph is more readable and visually appealing. The script then transposes the [`mean_values_updated`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y102sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A5%2C%22character%22%3A0%7D%7D%5D%2C%221439b749-8042-4d58-95f7-8178933abf00%22%5D "Go to definition") DataFrame so that the variables ('Performance', 'Ease_of_Use', 'Maintenance') become the x-axis labels. The transposed DataFrame is plotted as a bar graph using the [`plot`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y102sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A11%2C%22character%22%3A69%7D%7D%2C%7B%22uri%22%3A%7B%22scheme%22%3A%22file%22%2C%22authority%22%3A%22%22%2C%22path%22%3A%22%2FUsers%2Frgregs%2F.vscode%2Fextensions%2Fms-python.vscode-pylance-2024.9.2%2Fdist%2Fbundled%2Fstubs%2Fpandas%2Fcore%2Fframe.pyi%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22%22%7D%2C%22pos%22%3A%7B%22line%22%3A4178%2C%22character%22%3A8%7D%7D%5D%2C%221439b749-8042-4d58-95f7-8178933abf00%22%5D "Go to definition") method with the [`kind='bar'`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y102sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A11%2C%22character%22%3A74%7D%7D%5D%2C%221439b749-8042-4d58-95f7-8178933abf00%22%5D "Go to definition") parameter.
#
# The script proceeds to set the labels and title for the graph. The x-axis is labeled 'Variable', the y-axis is labeled 'Mean Values', and the title of the graph is set to 'Mean Performance, Ease of Use, and Maintenance by Testing Wave'. Finally, the script ensures that the x-axis labels are not rotated by setting the rotation parameter to 0 in the [`plt.xticks`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y102sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A8%2C%22character%22%3A10%7D%7D%5D%2C%221439b749-8042-4d58-95f7-8178933abf00%22%5D "Go to definition") function. The graph is then displayed using the [`plt.show`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22Y102sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A8%2C%22character%22%3A10%7D%7D%5D%2C%221439b749-8042-4d58-95f7-8178933abf00%22%5D "Go to definition") function.

# %% [markdown]
# <div style="background-color: #1f77b4; color: #FFFFE0; padding: 20px; border-radius: 5px; margin-top: 20px; border: 1px solid #b8daff;">
# <h3>Create a stacked bar chart </h3>
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Extract the 'Performance' column

Sat_Data_Labels = Sat_Data_Clean.copy()

performance_data = Sat_Data_Labels['Performance']

# change Testing_Wave to categorical and label it Wave #1, Wave #2, Wave #3

# Convert 'Testing_Wave' to a categorical variable with custom labels
Sat_Data_Labels['Testing_Wave'] = Sat_Data_Labels['Testing_Wave'].replace({1: 'Wave #1', 2: 'Wave #2', 3: 'Wave #3'})

# Define the mapping for the labels
labels = {
    1: '1-Strongly Disagree',
    2: '2-Disagree',
    3: '3-Somewhat Disagree',
    4: '4-Neither Agree nor Disagree',
    5: '5-Somewhat Agree',
    6: '6-Agree',
    7: '7-Strongly Agree'
}

# Apply the mapping to the specified columns
Sat_Data_Labels[['Performance', 'Ease_of_Use', 'Maintenance']] = Sat_Data_Labels[['Performance', 'Ease_of_Use', 'Maintenance']].replace(labels)

# Calculate the percentage of each rating (1 to 7) for the 'Performance' variable
rating_counts = performance_data.value_counts(normalize=True).sort_index() * 100

# Create a DataFrame for plotting
rating_percentages = pd.DataFrame(rating_counts).T
rating_percentages.columns = [f'{i}' for i in rating_percentages.columns]

# Create a stacked bar chart of the rating percentages for 'Performance'
rating_percentages.plot(kind='bar', stacked=True, figsize=(10, 10), color=plt.cm.tab20.colors)
plt.xlabel('Performance')
plt.ylabel('Percent of Response')
plt.title('Percent of Response for Performance by Rating')

# Show the labels in the legend
plt.legend(title='Rating', bbox_to_anchor=(1, 1))

# Show the plot
plt.show()

# %%
#### Show the percentage of each rating for 'Performance' by 'Testing_Wave'

# Group the data by 'Testing_Wave' and 'Performance'
grouped_data = Sat_Data_Labels.groupby(['Testing_Wave', 'Performance']).size().unstack(fill_value=0)

# Calculate the percentage of each rating (1 to 7) for the 'Performance' variable within each 'Testing_Wave'
rating_percentages = grouped_data.div(grouped_data.sum(axis=1), axis=0) * 100

# Create a stacked bar chart of the rating percentages for 'Performance' by 'Testing_Wave'
rating_percentages.plot(kind='bar', stacked=True, figsize=(20, 10), color=plt.cm.tab20.colors)
plt.xlabel('Testing Wave')
plt.ylabel('Percent of Response')
plt.title('Percent of Response for Performance by Rating and Testing Wave')

# Reverse the order of the labels in the legend
handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles[::-1], labels[::-1], title='Rating', bbox_to_anchor=(1, 1))

# Show the plot
plt.show()

# %% [markdown]
# <div style="background-color: #1f77b4; color: #FFFFE0; padding: 20px; border-radius: 5px; margin-top: 20px; border: 1px solid #b8daff;">
# <p>Code Explanation Detailed<p>
# </div>

# %% [markdown]
# This Python script uses the [`pandas`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X63sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A0%2C%22character%22%3A7%7D%7D%5D%2C%221a3c624b-cebc-4399-b3c1-26e095bc64d2%22%5D "Go to definition") and [`matplotlib`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X63sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A1%2C%22character%22%3A7%7D%7D%5D%2C%221a3c624b-cebc-4399-b3c1-26e095bc64d2%22%5D "Go to definition") libraries to analyze and visualize survey data related to performance ratings. Here's a step-by-step explanation:
#
# 1. **Import Libraries**:
#    ```python
#    import pandas as pd
#    import matplotlib.pyplot as plt
#    ```
#
# 2. **Extract 'Performance' Column**:
#    ```python
#    Sat_Data_Labels = Sat_Data_Clean.copy()
#    performance_data = Sat_Data_Labels['Performance']
#    ```
#    - Creates a copy of the [`Sat_Data_Clean`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X63sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A5%2C%22character%22%3A18%7D%7D%5D%2C%221a3c624b-cebc-4399-b3c1-26e095bc64d2%22%5D "Go to definition") DataFrame.
#    - Extracts the 'Performance' column into [`performance_data`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X63sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A7%2C%22character%22%3A0%7D%7D%5D%2C%221a3c624b-cebc-4399-b3c1-26e095bc64d2%22%5D "Go to definition").
#
# 3. **Convert 'Testing_Wave' to Categorical**:
#    ```python
#    Sat_Data_Labels['Testing_Wave'] = Sat_Data_Labels['Testing_Wave'].replace({1: 'Wave #1', 2: 'Wave #2', 3: 'Wave #3'})
#    ```
#    - Converts 'Testing_Wave' column values to categorical labels ('Wave #1', 'Wave #2', 'Wave #3').
#
# 4. **Define and Apply Label Mapping**:
#    ```python
#    labels = {
#        1: '1-Strongly Disagree',
#        2: '2-Disagree',
#        3: '3-Somewhat Disagree',
#        4: '4-Neither Agree nor Disagree',
#        5: '5-Somewhat Agree',
#        6: '6-Agree',
#        7: '7-Strongly Agree'
#    }
#    Sat_Data_Labels[['Performance', 'Ease_of_Use', 'Maintenance']] = Sat_Data_Labels[['Performance', 'Ease_of_Use', 'Maintenance']].replace(labels)
#    ```
#    - Defines a dictionary to map numerical ratings to descriptive labels.
#    - Applies this mapping to the 'Performance', 'Ease_of_Use', and 'Maintenance' columns.
#
# 5. **Calculate Rating Percentages**:
#    ```python
#    rating_counts = performance_data.value_counts(normalize=True).sort_index() * 100
#    rating_percentages = pd.DataFrame(rating_counts).T
#    rating_percentages.columns = [f'{i}' for i in rating_percentages.columns]
#    ```
#    - Calculates the percentage of each rating (1 to 7) for the 'Performance' variable.
#    - Creates a DataFrame [`rating_percentages`](command:_github.copilot.openSymbolFromReferences?%5B%22%22%2C%5B%7B%22uri%22%3A%7B%22scheme%22%3A%22vscode-notebook-cell%22%2C%22authority%22%3A%22github%22%2C%22path%22%3A%22%2Frgregs60%2FPython-Fall-2024-Notebooks%2FIn%20Class%20Demos%2FPython%20Demo%20%238%20-%20Python%20Homework%202.ipynb%22%2C%22query%22%3A%22%22%2C%22fragment%22%3A%22X63sdnNjb2RlLXZmcw%3D%3D%22%7D%2C%22pos%22%3A%7B%22line%22%3A32%2C%22character%22%3A0%7D%7D%5D%2C%221a3c624b-cebc-4399-b3c1-26e095bc64d2%22%5D "Go to definition") for plotting.
#
# 6. **Plot Rating Percentages**:
#    ```python
#    rating_percentages.plot(kind='bar', stacked=True, figsize=(20, 10), color=plt.cm.tab20.colors)
#    plt.xlabel('Performance')
#    plt.ylabel('Percent of Response')
#    plt.title('Percent of Response for Performance by Rating')
#    plt.legend(title='Rating', bbox_to_anchor=(1, 1))
#    plt.show()
#    ```
#    - Creates a stacked bar chart to visualize the rating percentages for 'Performance'.
#    - Configures the plot with labels, title, and legend.
#
# 7. **Analyze Ratings by 'Testing_Wave'**:
#    ```python
#    grouped_data = Sat_Data_Labels.groupby(['Testing_Wave', 'Performance']).size().unstack(fill_value=0)
#    rating_percentages = grouped_data.div(grouped_data.sum(axis=1), axis=0) * 100
#    ```
#    - Groups data by 'Testing_Wave' and 'Performance'.
#    - Calculates the percentage of each rating within each 'Testing_Wave'.
#
# 8. **Plot Ratings by 'Testing_Wave'**:
#    ```python
#    rating_percentages.plot(kind='bar', stacked=True, figsize=(20, 10), color=plt.cm.tab20.colors)
#    plt.xlabel('Testing Wave')
#    plt.ylabel('Percent of Response')
#    plt.title('Percent of Response for Performance by Rating and Testing Wave')
#    handles, labels = plt.gca().get_legend_handles_labels()
#    plt.legend(handles[::-1], labels[::-1], title='Rating', bbox_to_anchor=(1, 1))
#    plt.show()
#    ```
#    - Creates a stacked bar chart to visualize the rating percentages for 'Performance' by 'Testing_Wave'.
#    - Reverses the order of the legend labels to match the order of the stacked bars.
#    - Configures the plot with labels, title, and legend.

# %% [markdown]
# <div style="background-color: #1f77b4; color: #FFFFE0; padding: 20px; border-radius: 5px; margin-top: 20px; border: 1px solid #b8daff;">
# <h4>As I Mentioned in the Lecture with Rating Scales it is Useful to Recode Variables Combining Categories</h4>
# </div>

# %% [markdown]
# <div style="background-color: #1f77b4; color: #FFFFE0; padding: 20px; border-radius: 5px; margin-top: 20px; border: 1px solid #b8daff;">
# <h5>Recode Agree (5/6/7) Percentage<h5>
# </div>

# %%
# Top 3 Box Analysis - Four Steps

import matplotlib.pyplot as plt

Sat_Data_Num = Sat_Data_Clean.copy() # Reset the data to the original data


### 1-Copilot Prompt: add labels to the 'Testing_Wave' column as 'Wave 1', 'Wave 2', and 'Wave 3'


### 2-Copilot Prompt: Recode 'Performance', 'Ease_of_Use', and 'Maintenance' values: 1-4 as 0 and 5-7 as 100


### 3-Copilot Prompt: Group by 'Testing_Wave' and calculate the mean for each wave


### 4-Copilot Prompt: Create a line plot for the variables with 'Testing_Wave' as the x-axis, adding a legend, titles, and labels

# %% [markdown]
# <div style="background-color: #1f77b4; color: #FFFFE0; padding: 20px; border-radius: 5px; margin-top: 20px; border: 1px solid #b8daff;">
# <h5>Recode Agree (6/7) Percentage<h5>
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ensure Sat_Data_Clean is defined and contains the necessary columns
# Sat_Data_Clean should be a DataFrame with columns: 'Testing_Wave', 'Performance', 'Ease_of_Use', 'Maintenance'

# Reset the data to the original data
Sat_Data_Num = Sat_Data_Clean.copy()

# Set 'Testing_Wave' to categorical and label as 'Wave 1', 'Wave 2', 'Wave 3'
Sat_Data_Num['Testing_Wave'] = pd.Categorical(Sat_Data_Num['Testing_Wave'], categories=[1, 2, 3], ordered=True)
Sat_Data_Num['Testing_Wave'] = Sat_Data_Num['Testing_Wave'].cat.rename_categories(['Wave 1', 'Wave 2', 'Wave 3'])

# Recode 'Performance', 'Ease_of_Use', and 'Maintenance' values: 1-5 as 0 and 6-7 as 100
Sat_Data_Num['Performance_top'] = Sat_Data_Num['Performance'].apply(lambda x: 100 if x >= 6 else 0)
Sat_Data_Num['Ease_of_Use_top'] = Sat_Data_Num['Ease_of_Use'].apply(lambda x: 100 if x >= 6 else 0)
Sat_Data_Num['Maintenance_top'] = Sat_Data_Num['Maintenance'].apply(lambda x: 100 if x >= 6 else 0)

# Group by 'Testing_Wave' and calculate the mean for each wave
mean_values_by_wave = Sat_Data_Num.groupby('Testing_Wave').mean()

# Create a line plot for the variables with 'Testing_Wave' as the x-axis
plt.figure(figsize=(10, 6))
plt.plot(mean_values_by_wave.index, mean_values_by_wave['Performance_top'], marker='o', label='% Performance-Agree(6/7)')
plt.plot(mean_values_by_wave.index, mean_values_by_wave['Ease_of_Use_top'], marker='o', label='% Ease of Use-Agree(6/7)')
plt.plot(mean_values_by_wave.index, mean_values_by_wave['Maintenance_top'], marker='o', label='% Maintenance-Agree(6/7)')

# Set the labels and title
plt.xlabel('Testing Wave')
plt.ylabel('Mean Top 2 Percentage')
plt.title('Mean Top 2 Percentage for Performance, Ease of Use, and Maintenance by Testing Wave')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <div style="background-color: #1f77b4; color: #FFFFE0; padding: 20px; border-radius: 5px; margin-top: 20px; border: 1px solid #b8daff;">
# <h4>Maybe Top Box Strongly Agree (7) Percentage is worth looking at, if you think so add the code below<h4>
# <p> <p>
# <h4>Or Maybe You have another way of Showing This Data<h4>
# </div>

# %%
#### Code for Top Box Plot Strongly Agree (7)

# %% [markdown]
# <div style="background-color: #DC143C; color: #000000; padding: 20px; border-radius: 25px; margin-top: 30px; border: 1px solid #8B0000;"
# >
# <h1>End of Module</h1>
# </div>
